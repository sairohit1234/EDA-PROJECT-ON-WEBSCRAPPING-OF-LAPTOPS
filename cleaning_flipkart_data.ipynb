# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
df=pd.read_csv("laptop_data2.csv")

# %%
df
# Out:
#         Brand                                              Model    Display  \
# 0          HP                    HP Intel Core i5 12th Gen 1235U  15.6 inch
# 1        ASUS  ASUS Vivobook 15, with Backlit Keyboard, Intel...  15.6 Inch
# 2    Colorful         Colorful P15 Intel Core i7 12th Gen 12650H  15.6 Inch
# 3        ASUS      ASUS Vivobook 15 Intel Core i3 12th Gen 1215U  15.6 Inch
# 4        ASUS    ASUS Vivobook GO 15 AMD Ryzen 5 Quad Core 7520U  15.6 Inch
# ..        ...                                                ...        ...
# 979    Lenovo  Lenovo IdeaPad Slim 3 Intel Core i3 13th Gen 1...    14 Inch
# 980      ASUS  ASUS Vivobook 15, with Backlit Keyboard, Intel...  15.6 Inch
# 981        HP     HP (15s-fq5007TU) Intel Core i3 12th Gen 1215U    39.6 cm
# 982      DELL       DELL Vostro 3405 AMD Ryzen 5 Quad Core 3450U    14 inch
# 983      ASUS  ASUS TUF Gaming A17 with 90Whr Battery AMD Ryz...  17.3 Inch
#
# ...

# %%
df.isna().sum()
# Out:
# Brand               0
# Model               0
# Display             0
# Storage             5
# Selling_Price       1
# Original_price     19
# Discount           22
# Ratings           105
# Processor         124
# Ram                17
# dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize = (20, 6))
msno.matrix(df, ax = axes[0])
axes[0].set_title('Finding Null Values Using Missingno Matrix')
msno.bar(df, ax = axes[1])
axes[1].set_title('Finding Null Values Using Missingno BarPlot')
plt.show()
# Out:
# C:\Users\Batti\anaconda3\Lib\site-packages\missingno\missingno.py:61: UserWarning: Plotting a sparkline on an existing axis is not currently supported. To remove this warning, set sparkline=False.
#   warnings.warn(

# %%
df.duplicated().sum()
# Out:
# 427

# %%
df.loc[df['Original_price'].isnull(),'Original_price']=df.Selling_Price

# %%
df[df.Processor.isnull()]
# Out:
#       Brand                                            Model    Display  \
# 4      ASUS  ASUS Vivobook GO 15 AMD Ryzen 5 Quad Core 7520U  15.6 Inch
# 8    Lenovo             Lenovo Intel Core i5 12th Gen 12450H  14.1 Inch
# 59     ASUS                       ASUS TUF Gaming A14 (2024)    14 Inch
# 78       HP   HP Pavilion Plus AI PC Intel Core Ultra 5 125H    14 inch
# 82      MSI   MSI Sword 16 HX Intel Core i9 13th Gen 13980HX    16 Inch
# ..      ...                                              ...        ...
# 935      HP            HP Chromebook Plus Intel Core i3 N305    14 Inch
# 943    DELL       DELL Vostro AMD Ryzen 3 Dual Core R3-3250U      35 cm
# 953   Apple                       Apple MacBook Air Apple M3    13 Inch
# 963    Acer      Acer Nitro V Intel Core i5 14th Gen 14450HX    16 inch
# 973      HP           HP OMEN Intel Core i9 13th Gen 13900HX  16.1 inch
#
#         Storage Selling_Price Original_price Discount  Ratings Processor  \
# ...

# %%
df[df.Original_price==df.Selling_Price]
# Out:
#          Brand                                              Model    Display  \
# 18        Acer          Acer One 11 Intel Celeron Dual Core N4500  11.6 Inch
# 263         HP                 HP 15s AMD Ryzen 5 Hexa Core 5500U  15.6 inch
# 269       Acer                     Acer Extensa AMD Ryzen 5 7520U  15.6 Inch
# 292       Acer      Acer Chromebook Intel Core i5 10th Gen 10310U  13.5 Inch
# 298       Acer      Acer Chromebook Intel Celeron Dual Core N4500    14 inch
# 432     Lenovo            Lenovo LOQ AMD Ryzen 7 Octa Core 8845HS  15.6 Inch
# 543  Primebook         Primebook 4G Android Based MediaTek MT8788  11.6 Inch
# 559  Primebook         Primebook 4G Android Based MediaTek MT8788  11.6 Inch
# 592  Primebook         Primebook 4G Android Based MediaTek MT8788  11.6 Inch
# 663         HP                HP x360 Intel Core i3 7th Gen 7100U    14 inch
# 752         HP                         HP Intel Core Ultra 5 125H  15.6 inch
# ...

# %%
df.loc[df.Original_price == df.Selling_Price, 'Discount'] = "0% off"

# %%
df[df.Original_price == df.Selling_Price]
# Out:
#        Brand                                              Model  \
# 18      Acer          Acer One 11 Intel Celeron Dual Core N4500
# 263       HP                 HP 15s AMD Ryzen 5 Hexa Core 5500U
# 269     Acer                     Acer Extensa AMD Ryzen 5 7520U
# 292     Acer      Acer Chromebook Intel Core i5 10th Gen 10310U
# 298     Acer      Acer Chromebook Intel Celeron Dual Core N4500
# 663       HP                HP x360 Intel Core i3 7th Gen 7100U
# 868  SAMSUNG  SAMSUNG Galaxy Book3 Intel Core i5 13th Gen 1335U
# 908  Infinix    Infinix Y2 series Intel Core i3 11th Gen 1115G4
# 934   Lenovo  Lenovo IdeaPad 3 Intel Intel Celeron Dual Core...
#
#                 Storage  Selling_Price  Original_price Discount  Ratings  \
# 18           256 GB SSD          39999           39999   0% off      3.4
# 263          512 GB SSD          54479           54479   0% off      4.2
# 269          512 GB SSD          51999           51999   0% off      4.1
# ...

# %%
df.isna().sum()
# Out:
# Brand               0
# Model               0
# Display             0
# Storage             5
# Selling_Price       1
# Original_price      1
# Discount            4
# Ratings           105
# Processor         124
# Ram                17
# dtype: int64

# %%
df[df.Selling_Price.isna()]
# Out:
#     Brand                                           Model    Display  \
# 742   MSI  MSI Crosshair 15 Intel Core i7 12th Gen 12700H  15.6 Inch
#
#       Storage Selling_Price Original_price Discount  Ratings       Processor  \
# 742  1 TB SSD           NaN            NaN      NaN      4.5  Intel Core i7
#
#             Ram
# 742  16 GB DDR4

# %%
df=df[df['Selling_Price'].notna()]

# %%
df[df.Selling_Price.isna()]
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Display, Storage, Selling_Price, Original_price, Discount, Ratings, Processor, Ram]
# Index: []

# %%
df.isna().sum()
# Out:
# Brand               0
# Model               0
# Display             0
# Storage             5
# Selling_Price       0
# Original_price      0
# Discount            3
# Ratings           105
# Processor         124
# Ram                17
# dtype: int64

# %%
df[df.Discount.isna()]
# Out:
#     Brand                                              Model    Display  \
# 439  Acer           Acer Swift 5 Intel Core i5 8th Gen 8250U    14 inch
# 875  Acer  Acer Aspire 3D 15 SpatialLabs Edition Intel Co...  15.6 Inch
# 899    HP               HP 15q Intel Pentium Quad Core N5000  15.6 inch
#
#         Storage Selling_Price Original_price Discount  Ratings  \
# 439  256 GB SSD        81,998         82,799      NaN      4.0
# 875  512 GB SSD      1,49,990       1,50,999      NaN      NaN
# 899    1 TB HDD        25,490         25,531      NaN      4.2
#
#                     Processor         Ram
# 439            Intel Core i5          NaN
# 875                       NaN  16 GB DDR5
# 899  Intel Pentium Quad Core    4 GB DDR4

# %%
df['Selling_Price'] = df['Selling_Price'].str.replace(',', '').fillna(0).astype(int)
# Out:
# C:\Users\Batti\AppData\Local\Temp\ipykernel_22520\2517620217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Selling_Price'] = df['Selling_Price'].str.replace(',', '').fillna(0).astype(int)

# %%
df['Original_price'] = df['Original_price'].str.replace(',', '').fillna(0).astype(int)
# Out:
# C:\Users\Batti\AppData\Local\Temp\ipykernel_22520\1457191091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Original_price'] = df['Original_price'].str.replace(',', '').fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 983 entries, 0 to 983
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           983 non-null    object
#  1   Model           983 non-null    object
#  2   Display         983 non-null    object
#  3   Storage         978 non-null    object
#  4   Selling_Price   983 non-null    int32
#  5   Original_price  983 non-null    int32
#  6   Discount        980 non-null    object
#  7   Ratings         878 non-null    float64
#  8   Processor       859 non-null    object
#  9   Ram             966 non-null    object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 76.8+ KB

# %%
((((df['Original_price'] - df['Selling_Price']) / df['Original_price']) * 100))
# Out:
# 0      15.251255
# 1      37.842952
# 2      38.341153
# 3      32.733224
# 4      25.412782
#          ...
# 979    27.409693
# 980    38.671823
# 981    23.749364
# 982    25.902891
# 983    18.071954
# Length: 983, dtype: float64

# %%
a=df[df['Discount'].isna()]

# %%
a['Original_price'] - a['Selling_Price']/a['Original_price']
# Out:
# 439     82798.009674
# 875    150998.006682
# 899     25530.001606
# dtype: float64

# %%
a
# Out:
#     Brand                                              Model    Display  \
# 439  Acer           Acer Swift 5 Intel Core i5 8th Gen 8250U    14 inch
# 875  Acer  Acer Aspire 3D 15 SpatialLabs Edition Intel Co...  15.6 Inch
# 899    HP               HP 15q Intel Pentium Quad Core N5000  15.6 inch
#
#         Storage  Selling_Price  Original_price Discount  Ratings  \
# 439  256 GB SSD          81998           82799      NaN      4.0
# 875  512 GB SSD         149990          150999      NaN      NaN
# 899    1 TB HDD          25490           25531      NaN      4.2
#
#                     Processor         Ram
# 439            Intel Core i5          NaN
# 875                       NaN  16 GB DDR5
# 899  Intel Pentium Quad Core    4 GB DDR4

# %%
(((a['Original_price'] - a['Selling_Price']) / a['Original_price']) * 100).astype(str) + "% off"
# Out:
# 439    0.9674029879587918% off
# 875    0.6682163458036146% off
# 899    0.1605890877756453% off
# dtype: object

# %%
df.loc[df['Discount'].isna(), 'Discount'] = ((((df['Original_price'] - df['Selling_Price']) / df['Original_price']) * 100)).round(1).astype(str) + "% off"

# %%
df.isna().sum()
# Out:
# Brand               0
# Model               0
# Display             0
# Storage             5
# Selling_Price       0
# Original_price      0
# Discount            0
# Ratings           105
# Processor         124
# Ram                17
# dtype: int64

# %%
df[df.Storage.isna()]
# Out:
#       Brand                                              Model    Display  \
# 304    ASUS  ASUS Zenbook S 13 OLED 1 cm Thin & 1 kg Light,...   33.78 cm
# 458    ASUS  ASUS Zenbook 14X OLED Space Edition Touchscree...    14 inch
# 539    ASUS  ASUS ROG Strix G16 with 90WHr Battery Intel HX...    16 Inch
# 554    ASUS  ASUS ROG Strix G16 with 90WHr Battery Intel HX...    16 Inch
# 824  Lenovo  Lenovo IdeaPad 3 Chrome Intel Celeron Dual Cor...  15.6 Inch
#
#     Storage  Selling_Price  Original_price Discount  Ratings       Processor  \
# 304     NaN          89990          128990  30% off      4.1  Intel Core i5
# 458     NaN         104990          140990  25% off      4.2  Intel Core i5
# 539     NaN         125990          143990  12% off      4.3  Intel Core i7
# 554     NaN         125990          143990  12% off      4.3  Intel Core i7
# 824     NaN          17990           31490  42% off      NaN             NaN
#
#               Ram
# 304  16 GB LPDDR5
# 458  16 GB LPDDR5
# ...

# %%
df[df.Ram.isna()]
# Out:
#          Brand                                              Model    Display  \
# 29   Primebook                     Primebook Wifi MediaTek MT8183  11.6 Inch
# 134         HP        HP Chromebook Intel Celeron Quad Core N4120    14 Inch
# 223         HP                            HP AMD Athlon Dual Core  15.6 inch
# 231       Acer      Acer Chromebook Intel Celeron Dual Core N4020    14 Inch
# 233         HP        HP Chromebook Intel Celeron Dual Core N4020    14 Inch
# 349     Lenovo  Lenovo IdeaPad 3 Chromebook Intel Celeron Dual...  11.6 Inch
# 378     walker               walker Intel Celeron Dual Core N4020  14.1 inch
# 439       Acer           Acer Swift 5 Intel Core i5 8th Gen 8250U    14 inch
# 503         HP        HP Chromebook Intel Celeron Dual Core N4120    14 Inch
# 535       DELL                 DELL VOSTRO Intel Core i5 12th Gen    14 inch
# 543  Primebook         Primebook 4G Android Based MediaTek MT8788  11.6 Inch
# ...

# %%
df.duplicated().sum()
# Out:
#          Brand                                              Model     Storage  \
# 828  ZEBRONICS  ZEBRONICS Pro Series Z Intel Core i5 12th Gen ...  512 GB SSD
#
#      Selling_Price  Original_price  discount_in_percentage  Ratings  \
# 828          29990           60999                    50.0      3.8
#
#           Processor        Ram  display_in_inches
# 828  Intel Core i5   8 GB DDR4               15.6

# %%
df.Model.value_counts()
# Out:
# Model
# ASUS Vivobook 15, with Backlit Keyboard, Intel Core i5 12th Gen 1235U               68
# HP Intel Core i5 12th Gen 1235U                                                     43
# HP 15s AMD Ryzen 3 Quad Core 7320U                                                  40
# HP Laptop Intel Core i5 12th Gen 1235U                                              40
# ASUS Vivobook S 15 OLED Intel EVO H-Series Intel Core i5 13th Gen 13500H            40
#                                                                                     ..
# Infinix INBook X1 Pro Intel Core i7 10th Gen 1065G7                                  1
# Acer Intel Core i3 12th Gen 1215U                                                    1
# Infinix Zero Book Ultra AI PC Intel Core Ultra 7 155H                                1
# ASUS Vivobook 14X OLED For Creator, Intel H-Series Intel Core i5 13th Gen 13500H     1
# ASUS TUF Gaming A17 with 90Whr Battery AMD Ryzen 5 Hexa Core AMD R5-4600H            1
# ...

# %%
df=df.drop_duplicates()

# %%
df.Model.value_counts()
# Out:
# Model
# Lenovo LOQ Intel Core i5 12th Gen 12450HX                                                5
# ASUS TUF Gaming A15 AMD Ryzen 7 Octa Core 7435HS                                         5
# Lenovo IdeaPad 3 Intel Core i3 12th Gen 1215U                                            5
# ASUS Vivobook 15, with Backlit Keyboard, Intel Core i5 12th Gen 1235U                    5
# HP Intel Core i5 12th Gen 1235U                                                          4
#                                                                                         ..
# Colorful P15 Intel Core i7 13th Gen 13620H                                               1
# Lenovo Yoga 6 AMD Ryzen 5 Hexa Core 7530U                                                1
# ASUS ExpertBook B14 Intel Core i3 12th Gen 1215U                                         1
# ASUS Zenbook S 13 OLED 1 cm Thin & 1 kg Light, Intel EVO Intel Core i5 13th Gen 1335U    1
# ...

# %%
df[df.Model=="Lenovo LOQ Intel Core i5 12th Gen 12450HX"]
# Out:
#       Brand                                      Model    Display     Storage  \
# 23   Lenovo  Lenovo LOQ Intel Core i5 12th Gen 12450HX  15.6 inch  512 GB SSD
# 25   Lenovo  Lenovo LOQ Intel Core i5 12th Gen 12450HX   39.62 cm  512 GB SSD
# 303  Lenovo  Lenovo LOQ Intel Core i5 12th Gen 12450HX  15.6 Inch  512 GB SSD
# 518  Lenovo  Lenovo LOQ Intel Core i5 12th Gen 12450HX  15.6 inch  512 GB SSD
# 928  Lenovo  Lenovo LOQ Intel Core i5 12th Gen 12450HX  15.6 inch  512 GB SSD
#
#      Selling_Price  Original_price Discount  Ratings       Processor  \
# 23           61990           82690  25% off      4.1  Intel Core i5
# 25           59490           80090  25% off      4.3  Intel Core i5
# 303          49990           79990  37% off      4.1  Intel Core i5
# 518          49990           79990  37% off      NaN             NaN
# 928          71500           99500  28% off      NaN             NaN
#
#             Ram
# 23   12 GB DDR5
# 25   12 GB DDR5
# 303   8 GB DDR5
# ...

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Brand             0
# Model             0
# Display           0
# Storage           0
# Selling_Price     0
# Original_price    0
# Discount          0
# Ratings           0
# Processor         0
# Ram               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df[['Ratings', 'Processor']].isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Display, Storage, Selling_Price, Original_price, Discount, Ratings, Processor, Ram]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 438 entries, 0 to 983
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           438 non-null    object
#  1   Model           438 non-null    object
#  2   Display         438 non-null    object
#  3   Storage         438 non-null    object
#  4   Selling_Price   438 non-null    int32
#  5   Original_price  438 non-null    int32
#  6   Discount        438 non-null    object
#  7   Ratings         438 non-null    float64
#  8   Processor       438 non-null    object
#  9   Ram             438 non-null    object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 34.2+ KB

# %%
fig, axes = plt.subplots(1, 2, figsize = (20, 6))
msno.matrix(df, ax = axes[0])
axes[0].set_title('Finding Null Values Using Missingno Matrix')
msno.bar(df, ax = axes[1])
axes[1].set_title('Finding Null Values Using Missingno BarPlot')
plt.show()
# Out:
# C:\Users\Batti\anaconda3\Lib\site-packages\missingno\missingno.py:61: UserWarning: Plotting a sparkline on an existing axis is not currently supported. To remove this warning, set sparkline=False.
#   warnings.warn(

# %%
df=df.dropna()

# %%
new_df.isna().sum()
# Out:
# Brand             0
# Model             0
# Display           0
# Storage           0
# Selling_Price     0
# Original_price    0
# Discount          0
# Ratings           0
# Processor         0
# Ram               0
# dtype: int64

# %%
df.Model.value_counts()
# Out:
# Model
# ZEBRONICS Pro Series Z Intel Core i7 12th Gen 1255U                          4
# ASUS Vivobook 15 Intel Core i5 12th Gen 1235U                                4
# ASUS TUF Gaming F17                                                          4
# HP Intel Core i5 12th Gen 1235U                                              3
# Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 12450H                          3
#                                                                             ..
# ASUS Vivobook 15 Intel Pentium Gold 7505                                     1
# Acer Chromebook Intel Core i5 10th Gen 10310U                                1
# ASUS Vivobook Gaming Intel Core i5 9th Gen                                   1
# ASUS Vivobook 15 Intel Core i3 11th Gen 1115G4                               1
# ASUS TUF Gaming A17 with 90Whr Battery AMD Ryzen 5 Hexa Core AMD R5-4600H    1
# Name: count, Length: 359, dtype: int64

# %%
df.count()
# Out:
# Brand             438
# Model             438
# Display           438
# Storage           438
# Selling_Price     438
# Original_price    438
# Discount          438
# Ratings           438
# Processor         438
# Ram               438
# dtype: int64

# %%
df
# Out:
#         Brand                                              Model    Display  \
# 0          HP                    HP Intel Core i5 12th Gen 1235U  15.6 inch
# 1        ASUS  ASUS Vivobook 15, with Backlit Keyboard, Intel...  15.6 Inch
# 2    Colorful         Colorful P15 Intel Core i7 12th Gen 12650H  15.6 Inch
# 3        ASUS      ASUS Vivobook 15 Intel Core i3 12th Gen 1215U  15.6 Inch
# 5          HP                 HP 15s AMD Ryzen 3 Quad Core 7320U  15.6 Inch
# ..        ...                                                ...        ...
# 975      DELL        DELL Inspiron Intel Core i5 11th Gen 1135G7  15.6 inch
# 978      DELL                DELL core i5 Intel Core i5 12th Gen  15.6 inch
# 979    Lenovo  Lenovo IdeaPad Slim 3 Intel Core i3 13th Gen 1...    14 Inch
# 982      DELL       DELL Vostro 3405 AMD Ryzen 5 Quad Core 3450U    14 inch
# 983      ASUS  ASUS TUF Gaming A17 with 90Whr Battery AMD Ryz...  17.3 Inch
#
# ...

# %%
df.Processor.unique()
# Out:
# array(['Intel Core i5 ', 'Intel Core i7 ', 'Intel Core i3 ',
#        'AMD Ryzen 3 Quad Core ', 'Apple M2 ', 'Intel Core Ultra 9 ',
#        'Intel Celeron Dual Core ', 'Intel Core i9 ',
#        'AMD Ryzen 5 Hexa Core ', 'AMD Ryzen 7 Octa Core ',
#        'Intel Core Ultra 7 ', 'Intel Core Ultra 5 ', 'Intel Core 5 ',
#        'AMD Ryzen 3 Dual Core ', 'AMD Ryzen 5 Dual Core ',
#        'Intel Celeron Quad Core ', 'MediaTek MT8183 ',
#        'AMD Ryzen 3 Octa Core ', 'Apple M1 ', 'AMD Athlon Dual Core ',
#        'Intel Core 7 ', 'AMD Ryzen 5 Quad Core ',
#        'Stylish & Portable Thin and Light LaptopLPDDR5 RAM -faster & low power consumingFirmware TPM (Trusted Platform Module)-Improved Security of your PCFHD 1080p screen with 250 Nits brightnessLatest WiFi 6AMD Ryzen 5 ',
#        'Intel Pentium Gold ', 'AMD Ryzen Z1 HexaCore ',
#        'AMD APU Quad Core A12 ', 'AMD Ryzen 5 ',
#        'HD LCD Anti-glare DisplayIntel Core i3 ',
# ...

# %%
df['Processor'] = df['Processor'].replace(r'.*AMD Ryzen 5.*', 'AMD Ryzen 5', regex=True)
df['Processor'] = df['Processor'].replace(r'.*Intel Core i3.*', 'Intel Core i3', regex=True)
df[['Processor']].head()
# Out:
#                 Processor
# 0          Intel Core i5
# 1          Intel Core i5
# 2          Intel Core i7
# 3           Intel Core i3
# 5  AMD Ryzen 3 Quad Core

# %%
df.Processor.value_counts()
# Out:
# Processor
# Intel Core i5                             122
# Intel Core i3                              96
# AMD Ryzen 5                                62
# Intel Core i7                              38
# AMD Ryzen 7 Octa Core                      27
# Intel Celeron Dual Core                    20
# AMD Ryzen 3 Quad Core                      15
# AMD Ryzen 3 Dual Core                       9
# Intel Core Ultra 7                          8
# Intel Core Ultra 5                          7
# Intel Celeron Quad Core                     6
# Intel Core i9                               5
# AMD Athlon Dual Core                        5
# Intel Core Ultra 9                          3
# Apple M2                                    2
# Intel Pentium Gold                          2
# AMD Ryzen Z1 HexaCore                       1
# Intel Pentium Quad Core                     1
# Intel Pentium Dual Core                     1
# Powered by 11th Gen Intel Evo Core i5       1
# ...

# %%
df.Ram.value_counts()
# Out:
# Ram
# 8 GB DDR4              169
# 16 GB DDR4             103
# 16 GB DDR5              28
# 8 GB LPDDR5             22
# 4 GB DDR4               20
# 16 GB LPDDR5            19
# 8 GB LPDDR4X            19
# 16 GB LPDDR4X           17
# 16 GB LPDDR5X           13
# 32 GB LPDDR5X            6
# 8 GB DDR5                6
# 4 GB LPDDR4X             5
# 12 GB DDR5               3
# 32 GB DDR5               2
# 8 GB Unified Memory      2
# 24 GB DDR5               2
# 32 GB LPDDR5             1
# 8 GB LPDDR5X             1
# Name: count, dtype: int64

# %%
df.Discount.unique()
# Out:
# array(['15% off', '37% off', '38% off', '32% off', '20% off', '05% off',
#        '22% off', '29% off', '19% off', '25% off', '34% off', '33% off',
#        '0% off', '35% off', '40% off', '24% off', '16% off', '46% off',
#        '30% off', '36% off', '14% off', '23% off', '17% off', '28% off',
#        '27% off', '66% off', '48% off', '31% off', '13% off', '95% off',
#        '49% off', '42% off', '60% off', '44% off', '21% off', '51% off',
#        '10% off', '43% off', '50% off', '68% off', '54% off', '47% off',
#        '26% off', '39% off', '41% off', '52% off', '45% off', '18% off',
#        '09% off', '12% off', '61% off', '82% off', '86% off', '04% off',
#        '58% off', '78% off', '69% off', '89% off', '53% off', '97% off',
#        '11% off', '99% off', '0.2% off', '96% off'], dtype=object)

# %%
df['Discount'] = df['Discount'].str.replace('% off', '').astype(float)

# %%
df.rename(columns={'Discount': 'discount_in_percentage'}, inplace=True)

# %%
df.Display.nunique()
# Out:
# 27

# %%
df.Display.value_counts()
# Out:
# Display
# 15.6 Inch     157
# 15.6 inch      96
# 14 Inch        64
# 14 inch        50
# 16 inch        13
# 16 Inch        12
# 17.3 Inch       5
# 14.1 inch       4
# 15 inch         4
# 39.6 cm         4
# 35.56 cm        3
# 14.1 Inch       3
# 39.62 cm        2
# 11.6 Inch       2
# 7 Inch          2
# 17.3 inch       2
# 13.3 Inch       2
# 15.36 inch      2
# 16.1 Inch       2
# 11.6 inch       2
# 13.78 inch      1
# 15.3 Inch       1
# 13.3 inch       1
# 13.5 Inch       1
# 39 cm           1
# 13.6 Inch       1
# 8.8 inch        1
# Name: count, dtype: int64

# %%
def convert_cm_to_inches(value):
    if 'cm' in value:
        cm_value = float(value.split(' ')[0])
        inches_value = cm_value * 0.393701
        return f"{round(inches_value, 2)} Inch"
    return value

df['Display'] = df['Display'].apply(convert_cm_to_inches)


df[['Display']].head()
# Out:
#      Display
# 0  15.6 inch
# 1  15.6 Inch
# 2  15.6 Inch
# 3  15.6 Inch
# 5  15.6 Inch

# %%
df.Display.value_counts()
# Out:
# Display
# 15.6 Inch     159
# 15.6 inch      96
# 14 Inch        64
# 14 inch        50
# 16 inch        13
# 16 Inch        12
# 17.3 Inch       5
# 15.59 Inch      4
# 15 inch         4
# 14.1 inch       4
# 14.1 Inch       3
# 14.0 Inch       3
# 13.3 Inch       2
# 11.6 inch       2
# 17.3 inch       2
# 16.1 Inch       2
# 15.36 inch      2
# 7 Inch          2
# 11.6 Inch       2
# 13.5 Inch       1
# 15.35 Inch      1
# 13.3 inch       1
# 13.6 Inch       1
# 13.78 inch      1
# 15.3 Inch       1
# 8.8 inch        1
# Name: count, dtype: int64

# %%
df['display_in_inches'] = df['Display'].str.replace('Inch', 'inch')

# %%
df.display_in_inches.value_counts()
# Out:
# display_in_inches
# 15.6 inch     255
# 14 inch       114
# 16 inch        25
# 14.1 inch       7
# 17.3 inch       7
# 11.6 inch       4
# 15.59 inch      4
# 15 inch         4
# 13.3 inch       3
# 14.0 inch       3
# 15.36 inch      2
# 16.1 inch       2
# 7 inch          2
# 13.5 inch       1
# 15.35 inch      1
# 13.6 inch       1
# 13.78 inch      1
# 15.3 inch       1
# 8.8 inch        1
# Name: count, dtype: int64

# %%
df['display_in_inches']=df['display_in_inches'].str.split().str.get(0).astype(float)

# %%
df = df.drop(columns=['Display'])

# %%
df.describe()
# Out:
#        Selling_Price  Original_price    Ratings  display_in_inches
# count     438.000000      438.000000  438.00000         438.000000
# mean    50494.547945    72385.776256    4.18516          15.072397
# std     23976.430101    30977.005647    0.28225           1.075563
# min     10990.000000    20990.000000    2.80000           7.000000
# 25%     34540.000000    50753.750000    4.02500          14.000000
# 50%     45462.000000    66995.000000    4.20000          15.600000
# 75%     59990.000000    85835.250000    4.30000          15.600000
# max    198490.000000   256790.000000    5.00000          17.300000

# %%
df[df.Ratings==5]
# Out:
#        Brand                                              Model  \
# 114  Ultimus             Ultimus Neo Intel Core i3 10th Gen Neo
# 143      MSI             MSI Claw AI PC Intel Core Ultra 7 155H
# 235   Lenovo  Lenovo IdeaPad 3 Chrome Intel Celeron Dual Cor...
# 454     Acer          Acer Nitro V AMD Ryzen 7 Octa Core 7735HS
# 594     ASUS                         ASUS AMD Ryzen 7 Octa Core
# 665      MSI          MSI Thin 15 Intel Core i7 13th Gen 13620H
# 969     Acer  Acer Chromebook Plus Intel Core i3 13th Gen 1315U
#
#                  Storage  Selling_Price  Original_price  \
# 114           256 GB SSD          21990           35990
# 143             1 TB SSD          64990           99990
# 235  128 GB EMMC Storage          16990           30790
# 454           512 GB SSD          67990           89999
# 594             1 TB SSD          90400          121000
# 665           512 GB SSD          67990           81990
# 969           256 GB SSD          32990           52999
# ...

# %%
path=r"C:\Users\Batti\OneDrive\Desktop\Innomatics\regex\Project\Cleaned_laptop_data2.csv"
df.to_csv(path,index=False)

# %%
df
# Out:
#         Brand                                              Model     Storage  \
# 0          HP                    HP Intel Core i5 12th Gen 1235U  512 GB SSD
# 1        ASUS  ASUS Vivobook 15, with Backlit Keyboard, Intel...  512 GB SSD
# 2    Colorful         Colorful P15 Intel Core i7 12th Gen 12650H  512 GB SSD
# 3        ASUS      ASUS Vivobook 15 Intel Core i3 12th Gen 1215U  512 GB SSD
# 5          HP                 HP 15s AMD Ryzen 3 Quad Core 7320U  512 GB SSD
# ..        ...                                                ...         ...
# 975      DELL        DELL Inspiron Intel Core i5 11th Gen 1135G7    1 TB HDD
# 978      DELL                DELL core i5 Intel Core i5 12th Gen  512 GB SSD
# 979    Lenovo  Lenovo IdeaPad Slim 3 Intel Core i3 13th Gen 1...  512 GB SSD
# 982      DELL       DELL Vostro 3405 AMD Ryzen 5 Quad Core 3450U  256 GB SSD
# 983      ASUS  ASUS TUF Gaming A17 with 90Whr Battery AMD Ryz...  512 GB SSD
#
# ...

# %%
df.Brand.value_counts()
# Out:
# Brand
# Lenovo       96
# HP           90
# ASUS         85
# Acer         46
# MSI          31
# DELL         31
# Infinix      25
# ZEBRONICS    10
# SAMSUNG       8
# Ultimus       5
# Colorful      4
# Apple         3
# CHUWI         2
# realme        2
# Name: count, dtype: int64

# %%
import Math

# %%
df.describe()
# Out:
#        Selling_Price  Original_price  discount_in_percentage    Ratings  \
# count     438.000000      438.000000              438.000000  438.00000
# mean    50494.547945    72385.776256               31.852055    4.18516
# std     23976.430101    30977.005647               14.477526    0.28225
# min     10990.000000    20990.000000                0.000000    2.80000
# 25%     34540.000000    50753.750000               24.000000    4.02500
# 50%     45462.000000    66995.000000               32.000000    4.20000
# 75%     59990.000000    85835.250000               39.000000    4.30000
# max    198490.000000   256790.000000               99.000000    5.00000
#
#        display_in_inches
# count         438.000000
# mean           15.072397
# std             1.075563
# min             7.000000
# 25%            14.000000
# 50%            15.600000
# 75%            15.600000
# max            17.300000

# %%
pd.read_csv(path)
# Out:
#         Brand                                              Model     Storage  \
# 0          HP                    HP Intel Core i5 12th Gen 1235U  512 GB SSD
# 1        ASUS  ASUS Vivobook 15, with Backlit Keyboard, Intel...  512 GB SSD
# 2    Colorful         Colorful P15 Intel Core i7 12th Gen 12650H  512 GB SSD
# 3        ASUS      ASUS Vivobook 15 Intel Core i3 12th Gen 1215U  512 GB SSD
# 4          HP                 HP 15s AMD Ryzen 3 Quad Core 7320U  512 GB SSD
# ..        ...                                                ...         ...
# 433      DELL        DELL Inspiron Intel Core i5 11th Gen 1135G7    1 TB HDD
# 434      DELL                DELL core i5 Intel Core i5 12th Gen  512 GB SSD
# 435    Lenovo  Lenovo IdeaPad Slim 3 Intel Core i3 13th Gen 1...  512 GB SSD
# 436      DELL       DELL Vostro 3405 AMD Ryzen 5 Quad Core 3450U  256 GB SSD
# 437      ASUS  ASUS TUF Gaming A17 with 90Whr Battery AMD Ryz...  512 GB SSD
#
# ...

# %% [markdown]
# ### Outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.set(style="whitegrid")


plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Selling_Price'])
plt.title('Boxplot of Selling Price with Outliers')
plt.show()


plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Original_price'])
plt.title('Boxplot of Original Price with Outliers')
plt.show()


plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Ratings'])
plt.title('Boxplot of Ratings')
plt.show()

# %%
df.sort_values(by=['Selling_Price'])
# Out:
#        Brand                                              Model  \
# 129       HP                      HP Chromebook MediaTek MT8183
# 216  Ultimus         Ultimus PRO Intel Celeron Dual Core N4020C
# 865  Ultimus              Ultimus Intel Celeron Dual Core N4020
# 428     Acer      Acer Chromebook Intel Celeron Dual Core N4500
# 452     Acer      Acer Chromebook Intel Celeron Dual Core N4500
# ..       ...                                                ...
# 848  SAMSUNG  SAMSUNG Galaxy Book4 Pro Evo AI PC Intel Core ...
# 882      MSI  MSI Crosshair 16 HX Intel Core i7 14th Gen 147...
# 325   Lenovo  Lenovo IdeaPad Pro 5 2K OLED AI PC Intel Core ...
# 142  SAMSUNG  SAMSUNG Galaxy Book4 Pro Evo AI PC Intel Core ...
# 22    Lenovo  Lenovo Legion Pro 5 Intel Core i9 14th Gen 149...
#
#                  Storage  Selling_Price  Original_price  \
# 129   32 GB EMMC Storage          10990           34554
# 216  128 GB EMMC Storage          11990           24990
# ...
